# %% [markdown]
# # **Test 1 - LAB**
#
# Please read the following instructions carefully before beginning the lab part of test 1:
#
#
# *   This test consists 5 questions.
# *   Work through the problems in order to stay organized and ensure that no questions are missed.
# *   Read each problem carefully and show comment using # sign in the code cell if necessary to receive full credit.
# *   Academic dishonesty will not be tolerated. Cheating or unauthorized assistance will result in a zero on the test.
# "LACC expects students to be honest and ethical at all times.  Be advised that instructors will refer cases of suspected cheating to the Dean of Student Services for possible disciplinary action.  Cheating is a violation of academic integrity and Board Rule 9803.12.  Penalties for cheating may include a grade of zero or “F” on an exam or paper, or even suspension from the College."
# *   Do not share your work with other students.
#
# After you have completed the test, be sure to submit your work on Canvas!
#
#
#
# ---
#
# Before you begin the test, be sure to run the code cell below to install the Python packages and library.

# %%
# import NumPy and SciPy
import numpy as np
import scipy.linalg as sp

print("Libraries imported successfully.✅ \n Begin the Test 1 - LAB now.")

# %% [markdown]
# ##  1️⃣ **Question 1** (2 pts.)
# Use the code cell below to create a 3x5 matrix using NumPy and with the matrix satisfying the following requirements:
#
# *   No repeated entries
# *   0 is one of the entries
# *   Has at least one entries that is a negative value
# *   Name the matrix with your first name

# %%
# Create the matrix with the requirements listed above 👇👇👇



# Print the matrix 👇👇👇

# %% [markdown]
# ##  2️⃣ **Question 2** (2 pts.)
#
# Given
# $$
# A = \left[
# \begin{array}{cc}
# 4 & -5 & 0\\
# -2 & 3 & 1\\
# 6 & 2 & -3
# \end{array}
# \right]
# $$
# and
# $$
# B = \left[
# \begin{array}{cc}
# 1 & -4 \\
# -1 & 3 \\
# 2 & 5
# \end{array}
# \right]
# $$
#
# Perform a matrix multiplication in the code cell below.

# %%
# Input the matrices 👇👇👇



# Multiply matrix A times matrix B 👇👇👇



# Print the result 👇👇👇

# %% [markdown]
# ##  3️⃣ **Question 3** (5 pts.)
#
# $LU$ factorization decomposes a square matrix $A$ into a unit lower triangular matrix $L$ and an upper triangular matrix $U$. It significantly reduces the number of operations for large systems compared to Gaussian elimination.
#
# Find the _permutation matrix_ $P$, _lower triangular matrix_ $L$, and _upper triangular matrix_ $U$.
#
# Use $P$, $L$, and $U$ to solve the system _Ax_ = _b_:
#
# $$
# \left[
# \begin{array}{cc}
# 4 & -5 & 0\\
# -2 & 3 & 1\\
# 6 & 2 & -3
# \end{array}
# \right]
# \left[\begin{array}{cc}
# x_1 \\
# x_2 \\
# x_3
# \end{array}\right]
# =
# \left[
# \begin{array}{cc}
# 22 \\
# -19 \\
# 35
# \end{array}
# \right]
# $$

# %%
# Find P, L, and U for the matrix A in Question 2 👇👇👇



# Print P, L, and U (Be sure to label P, L, U in the output)👇👇👇





# If y = Ux, write the code to solve PLy = b for y
# and print y (Be sure to label y in the output) 👇👇👇



# Write the code to solve Ux = y
# and print the result of x (Be sure to label x in the output) 👇👇👇

# %% [markdown]
# ##  4️⃣ **Question 4** (3 pts.)
# Solve the system _Ax_ = _b_ directly using matrices _A_ and _b_:
#
# $$
# \left[
# \begin{array}{cc}
# 4 & -5 & 0\\
# -2 & 3 & 1\\
# 6 & 2 & -3
# \end{array}
# \right]
# \left[\begin{array}{cc}
# x_1 \\
# x_2 \\
# x_3
# \end{array}\right]
# =
# \left[
# \begin{array}{cc}
# 22 \\
# -19 \\
# 35
# \end{array}
# \right]
# $$

# %%
# Solve the system directly using matrices A and b 👇👇👇




# Print the result with the output
# stated "The solution to the system Ax = b is {your result}."👇👇👇

# %% [markdown]
# ##  5️⃣ **Question 5** 💡**Reflection Question**💡 (3 pts.)
#
# With your work in Questions 3 and 4, how do those approaches, _LU_ decomposition and solving system using NumPy, compare with coding Gaussian Elimination line by line to solve a system of linear equation? Discuss their effectiveness when solving a real application that involves systems of many linear equations.

# %% [markdown]
# 💻 Your response to **Question 5** is: 💻 👇👇👇
