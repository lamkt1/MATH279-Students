# %% [markdown]
# # **Test 2 - LAB**
#
# Please read the following instructions carefully before beginning the lab part of test 2:
#
#
# *   This test consists 5 questions.
# *   Work through the problems in order to stay organized and ensure that no questions are missed.
# *   Read each problem carefully and show comment using # sign in the code cell if necessary to receive full credit.
# *   Academic dishonesty will not be tolerated. Cheating or unauthorized assistance will result in a zero on the test.
# "LACC expects students to be honest and ethical at all times.  Be advised that instructors will refer cases of suspected cheating to the Dean of Student Services for possible disciplinary action.  Cheating is a violation of academic integrity and Board Rule 9803.12.  Penalties for cheating may include a grade of zero or “F” on an exam or paper, or even suspension from the College."
# *   Do not share your work with other students.
#
# After you have completed the test, be sure to submit your work on Canvas!
#
#
#
# ---
#
# Before you begin the test, be sure to run the code cell below to install the Python packages and library.

# %%
# import library
import numpy as np
import sympy as sy
import pandas as pd

# import scikit-learn
from sklearn.decomposition import PCA

print("Libraries imported successfully.✅ \n Begin the Test 2 - LAB now.")

# %% [markdown]
# ##  1️⃣ **Question 1** (6 pts.)
# Use the code cell below to find scalars m, p, and q such that:
# $$m(0, 1, 5) + p(-3, 4, 7) + q(2, -5, 1) =(-28, 51, 47)$$
# and satisfy the following requirements:
#
# *   Set up the coefficient matrix _A_
# *   Set up the target vector _b_
# *   Find the scalars
# *   Print the result of each scalar (m, p, and q) with each clearly labels

# %%
# Coefficient matrix A👇👇👇



# Target vector b👇👇👇



# Solve scalars m, p, and q 👇👇👇



# Print the results for scalars m, p, and q 👇👇👇

# %% [markdown]
# ##  2️⃣ **Question 2** (3 pts. for each part)
#
# Determine if the following vectors are linearly independent:
#
#
# A.   $v_1=(2,4,-5), v_2=(1,-3,2), v_3=(1,2,5)$ using the approach of solving the system
#
# B.   $v_1=(-1,3,0), v_2=(2,-6,0), v_3=(-4,8,1)$ using the approach of evaluating the determinant
#
# Then, at the end of each part, provide your findings and justify your results.

# %%
# Given v1=(2,4,-5), v2=(1,-3,2), v3=(1,2,5)
# Approach A: Solving the system 👇👇👇

# %% [markdown]
# **Answer:**
#
# Vectors $v_1=(2,4,-5), v_2=(1,-3,2), v_3=(1,2,5)$ is:
#
# 👉👉👉

# %%
# Given v1=(-1,3,0), v2=(2,-6,0), v3=(-4,8,1)
# APPROACH B: Evaluating the determinant 👇👇👇

# %% [markdown]
# **Answer:**
#
# Vectors $v_1=(-1,3,0), v_2=(2,-6,0), v_3=(-4,8,1)$ is:
#
# 👉👉👉

# %% [markdown]
# ##  3️⃣ **Question 3** (5 pts.)
#
# Given
# $$
# \left[
# \begin{array}{cc}
# 2 & 4 & -1 & 2\\
# 3 & 6 & 5 & 4\\
# 4 & 8 & 1 & 2\\
# -1 & -2 & 3 & 1\\
# 2 & 4 & 1 & 0\\
# \end{array}
# \right]
# $$
# Find the basis for the column space of _A_ using `.rref()`

# %%
# Complete Matrix B with the information provided above.👇👇👇
B = sy.Matrix([[2,4,-1,2],???])

# Find the Reduced Row Echelon Form 👇👇👇

# %% [markdown]
# The basis for the column space of A is: 👇👇👇

# %% [markdown]
# ---
#
#
# # Working with Real Dataset
#
# ### About This Dataset
# `PassengerId`: Per capita crime rate by town.
#
# `survived`: Survival (0 = No, 1 = Yes)
#
# `pclass`: Ticket class
#
# `name`: Name
#
# `sex`: Sex
#
# `age`: Age in years
#
# `sibsp`: # of siblings / spouses aboard the Titanic
#
# `parch`: # of parents / children aboard the Titanic
#
# `ticket`: Ticket number
#
# `fare`: Passenger fare
#
# `cabin`: Cabin number
#
# `embarked`: Port of Embarkation (C = Cherbourg, Q = Queenstown, S = Southampton)
#
# ### Goal
#
# Use the **Titanic Dataset** to answer Questions 4 and 5

# %%
# Load dataset into colab from GitHub
url = 'https://raw.githubusercontent.com/lamkt1/MATH279-Students/refs/heads/main/Titanic.csv'
titanic_df = pd.read_csv(url)

titanic_df.info()
titanic_df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# ...

# %% [markdown]
# ##  4️⃣ **Question 4** (2 pts.)
# Based on the output of titanic_df, how many observations (passenger information)?
#
# 👉👉👉

# %% [markdown]
# ##  5️⃣ **Question 5** (3 pts.)
#
# Based on the output of titanic_df, are there any missing data? If so, which variable(s) and how many data are missing in each of those variable(s)?
#
# 👉👉👉

# %%
#Run this CODE CELL.
print("This is the end of the Lab part of Test 2.")
print("Be sure to submit your Test 2 Lab to Canvas.")
