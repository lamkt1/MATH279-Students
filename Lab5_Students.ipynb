# %% [markdown]
# 💯 **Each reflection question is worth 2 points. Points for the exercises are specified accordingly.**

# %% [markdown]
# ---
# # 🎯**Learning Goals**
#
# By the end of this lab, you will be able to:
# 1. Implement the Gram-Schmidt process
# 2. Construct orthonormal bases from linearly independent vectores
# 3. Verify orthogonality numerically
# 4. Understand the Least Squares optimization problem

# %% [markdown]
# ---
#
# # Part 0: Setup – Install Python packages and library
#
# Run the code below.

# %%
# import numpy and pandas
import numpy as np
import pandas as pd

# import library for visualization
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ---
#
# # Part 1: Vector Operations (6 pts.)
# (2 points from completing the codes in code cells + 4 points from Reflection Questions)

# %%
# Create two vectors
v1 = np.array([1, 2, 3])
v2 = np.array([4, 5, 6])

# Find dot product of two vectors
dot_product = np.dot(v1, v2)
print("Dot product of v1 and v2:", dot_product)

# Compute magnitude of a vector
magnitude = np.linalg.norm(v1)
print("Magnitude of v1:", magnitude)

# Find unit vector of v1  👇👇👇
unit_vector = ???
print("Unit vector of v1:", unit_vector)

# %% [markdown]
# # 💡**Reflection Questions**💡
#
# 1. What does dot product of two vectors tell us?
#
# 2. What does it mean when the dot product of two vectors is positive, zero, or negative?

# %% [markdown]
# 💻 Your response to **Question 1** is: 💻
#
#
# 💻 Your response to **Question 2** is: 💻

# %% [markdown]
# ---
#
# # Part 2: Gram–Schmidt Process (2 pts.)
#
# The Gram-Schmidt process is a linear algebra algorithm used to transform a set of linearly independent vectors into an orthogonal or orthonormal set that spans the same subspace.
#
# The core idea is to take each vector in the set and subtract the components that point in the direction of the already-processed vectors.
#
# **Steps:**
#
#
# 1.   Simply set the first orthogonal vector to match the first original vector: $$v_1=x_1$$
# 2.   Take the second original vector $x_2$ and subtract its projection onto the first vector $v_1$: $$v_2=x_2-proj_{v_1} (x_2)$$
# 3.   Take the third original vector $x_3$ and subtract its projections onto both of the previously established vectors $v_1$ and $v_2$: $$v_3=x_3-proj_{v_1} (x_3)-proj_{v_2} (x_3)$$
# 4.   Continue this pattern for any remaining vectors. To find the *k*-th orthogonal vector, subtract its projections onto all previously found orthogonal vectors: $$v_k=x_k-proj_{v_1} (x_k)-proj_{v_2} (x_k)-...-proj_{v_{k-1}} (x_k)$$

# %%
# Define vectors
x1 = np.array([1, 0, 0])
x2 = np.array([1, 1, 0])

# Normalize vector x1 (unit vector of x1)
u1 = x1 / np.linalg.norm(x1)

# Projection of x2 onto the first vector x1
# dot product of x2 and u1 times u1
v2 = x2 - np.dot(x2, u1) * u1

# Normalize vector v2
u2 = v2 / np.linalg.norm(v2)

# %%
# Verify othogonality of u1 and u2  👇👇👇
print("Dot product of u1 and u2:", ???)

# %% [markdown]
# ---
#
# # Part 3: Least Squares Problems
#
# The NumPy function `np.linalg.lstsq(feature_matrix, target)` solves the least squares problem by computing the best-fit solution to a linear system and minimizing the squared error. It is used in linear regression when there is no exact solution or the system is overdetermined.
#
# In a real dataset, we usually have more observations than the number of features. Therefore, no exact solution fits every data point perfectly, so `np.linalg.lstsq(feature_matrix, target)` funds the coefficients that minimize the overall squaredd error.
#
# **Understand the Function**
# `np.linalg.lstsq(feature_matrix, target)`
#
# *   `feature_matrix`: matrix of the study (shape: observations x features)
# *   `target`: target vector (shape: observation)
#
# **Output:**
#
#
# *   **Solution**: weights or scalar in the linear combination of the system
# *   **Residuals**: sum of squared errors
# *   **Rank**: rank of `feature_matrix`
# *   **Singular value**: factor that the matrix stretches or scales data in different directions, is used for stability
#
#     *   Large singular value indicates strong, important direction in the data
#     *   Small singular value indicates weak, nearly redundant direction
#     *   Zero (or close to zero) means no information in that direction
#     *   For small singular values, `np.linalg.lstsq(feature_matrix, target)` reduces the weight of a direction when computing the solution.

# %% [markdown]
# # Working with Real Dataset (42 points)
#
# (26 points from completing the codes in code cells + 16 points from Reflection Questions)
#
#
# ## **Medical Cost Personal Datasets**
# The dataset contains records with variables such as age, BMI, smoking status, region, and medical insurance charges. It is commonly used for regression and predictive modeling exercises.
#
#
# ### About This Dataset
# `age`: age of primary beneficiary
#
# `bmi`: Body mass index, providing an understanding of body, weights that are relatively high or low relative to height,
# objective index of body weight (kg / m ^ 2) using the ratio of height to weight, ideally 18.5 to 24.9
#
# `children`: Number of children covered by health insurance / Number of dependents
#
# `smoker`: Smoking
#
# `region`: the beneficiary's residential area in the US, northeast, southeast, southwest, northwest
#
# `charges`: Individual medical costs billed by health insurance
#
# ### Goal
#
# You are a data scientist building a model to predict insurance charges using age and BMI.
# We assume a linear model $$y=\beta_0 + \beta_1 x_1 + \beta_2 x_2$$, where
#
# *   $y$ = insurance charges
# *   $x_1$ = age
# *   $x_2$ = bmi
# *   $\beta$ = weights of features
#
# We would like to minimize the sum of squares: $$\sum_{i=1}^{n} (y_i - \hat{y}_i)^2$$

# %%
# Load dataset into colab from GitHub
url = 'https://raw.githubusercontent.com/lamkt1/MATH279-Students/refs/heads/main/insurance.csv'
insurance_df = pd.read_csv(url)

# Display the first five rows of dataset 👇👇👇
print(???)

# Identify the dimensions of the dataset 👇👇👇
print(???)

# %% [markdown]
# # 💡**Reflection Questions**💡
#
# 3. What do rows and columns represent in this dataset?
#
# 4. Categorical and numerical are the two primary classifications of data used in statistics and data analysis.Categorical data, also known as qualitative data, describes qualities, characteristics, or labels rather than numerical values. Numerical data represents measurable amounts or quantities. Which variables are categorical?
#
# 5. Based on the prompt of this exercise, which of the columns in the dataset shuold be selected as our target variable?

# %% [markdown]
# 💻 Your response to **Question 3** is: 💻
#
#
# 💻 Your response to **Question 4** is: 💻
#
#
#
# 💻 Your response to **Question 5** is: 💻

# %%
# Provide a concise summary or information of the dataset 👇👇👇

# %% [markdown]
# # 💡**Reflection Questions**💡
#
# 6. How many observations in total?
#
# 7. Are there any null values in any columns? If so, please identify the column(s).

# %% [markdown]
# 💻 Your response to **Question 6** is: 💻
#
#
# 💻 Your response to **Question 7** is: 💻

# %%
# Summary Statistics
insurance_df.describe()

# %% [markdown]
# # 💡**Reflection Questions**💡
#
# 8. The dataset contains 7 columns, so why does running `insurance_df.describe()` display only 4 columns?

# %% [markdown]
# 💻 Your response to **Question 8** is: 💻

# %%
# Visualizing the data "Age vs Charges" using scatterplot
sns.scatterplot(data=insurance_df, x="age", y="charges")
plt.title("Age vs Charges")
plt.show()

# %%
# Visualizing the data "BMI vs Charges" using scatterplot👇👇👇
???
plt.title("BMI vs Charges")
plt.show()

# %%
# Visualizing the data "Smoker vs Charges" using boxplot 👇👇👇
sns.boxplot(???)
plt.title("Smoker vs Charges")
plt.show()

# %%
# .values attribute returns a NumPy representation of the DataFrame
# extracts the underlying data and returns it as a NumPy array
X = insurance_df[["age","bmi", "children"]].values
y = insurance_df["charges"].values

# %%
# Compute the least-square solution to the linear matrix equation 👇👇👇
w, residuals, rank, s =

print("Weights:", w)
print("Residuals:", residuals)
print("Rank:", rank)
print("Singular values:", s)

# %%
# Find the predicted value with the weights found above 👇👇👇
y_pred =

# Approximate error (actual value minus predicted value) 👇👇👇
error =

# Calculuate error relative to target 👇👇👇
relative_error =

# Print error 👇👇👇
print("Prediction error:", ???)

# Print relative error 👇👇👇
print("Relative prediction error:", ???)

# %% [markdown]
# # 💡**Reflection Questions**💡
#
# 9. Relative prediction error in data science measures the magnitude of an error relative to the actual value. Low relative error indicates high model accuracy, while high relative error indicates poor performance. Use the following guidline to interpret the relative prediction error found in the code cell above.
#
# *   0% - 5%: high precision (excellent)
# *   5% - 15%: strong model
# *   15% - 25%: moderate (usable with caution)
# *   25% - 50%: fairly weak (needs to be reviewed)
# *   $>$ 50%: poor model (not reliable)

# %% [markdown]
# 💻 Your response to **Question 9** is: 💻

# %%
# Customize the plot
plt.figure(figsize=(10, 10))

# Create scatter plot to show the actual and predicted insurance charges
plt.scatter(y, y_pred, alpha=0.5)

# Ideal prediction line
plt.plot(
    [y.min(), y.max()],
    [y.min(), y.max()],
    color='red',
    linewidth=2
)

plt.xlabel("Actual Charges")
plt.ylabel("Predicted Charges")
plt.title("Actual vs Predicted Insurance Charges")

plt.grid(True)
plt.show()

# %% [markdown]
# # **Solve Least Squares with Normal Equations**

# %%
# adds an intercept column y = b0 + b1 x1 + b2 x2 + ... bn xn
# np.ones fills every single cell with 1.0
# (X.shape[0], 1) defines the shape: number of rows in X by 1 column
ones = np.ones((X.shape[0], 1))

# stack the intercept column into the dataset
X = np.hstack([ones, X])

# print the first 5 rows 👇👇👇

# %%
# solve X * beta = y <-- y is the actual value
# X.T @ X * beta = X.T @ y
# X.T @ X becomes a square matrix
# take its inverse to both sides to solve for beta
beta = np.linalg.inv(X.T @ X) @ X.T @ y

print(beta)

# %%
# Calculate the the predicted value by multiplying the features and weights 👇👇👇
y_prediction =

# %%
# Calculate the mean squared error
mse = np.mean((y - y_prediction)**2)

print("MSE:", mse)

# %% [markdown]
# # 💡**Reflection Questions**💡
#
# 10. What does the mean squared error (MSE) result indicate in this case? Based on the MSE value, do you think the model provides good predictions?

# %% [markdown]
# 💻 Your response to **Question 10** is: 💻

# %%
#Run this CODE CELL.
print("Congratulations!🎉 You have completed Lab 5.")
print("Be sure to submit your Lab 5 work to Canvas.")
